# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
import requests
from config import weather_api_key

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="
weather_url = base_url + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = weather_url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind})
                          
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | tasiilaq
# Processing Record 3 of Set 1 | lata
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | georgetown
# Processing Record 6 of Set 1 | fevralsk
# City not found. Skipping...
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | sisimiut
# Processing Record 9 of Set 1 | port-gentil
# Processing Record 10 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 1 | biak
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | wau
# Processing Record 14 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 1 | knysna
# Processing Record 16 of Set 1 | vanimo
# Processing Record 17 of Set 1 | ponta do sol
# Processing Record 18 of Set 1 | birao
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 1 | half moon bay
# Processing Record 26 of Set 1 | santa maria
# Processing Record 27 of Set 1 | bubaque
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | gangapur
# Processing Record 30 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 1 | semnan
# Processing Record 32 of Set 1 | nago
# Processing Record 33 of Set 1 | hvide sande
# Processing Record 34 of Set 1 | yumen
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | kabare
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | marienburg
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | lavrentiya
# Processing Record 41 of Set 1 | anadyr
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | albany
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | foundiougne
# Processing Record 47 of Set 1 | upernavik
# Processing Record 48 of Set 1 | goderich
# Processing Record 49 of Set 1 | udachnyy
# Processing Record 50 of Set 1 | lebu
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | naze
# Processing Record 3 of Set 2 | constitucion
# Processing Record 4 of Set 2 | visnes
# Processing Record 5 of Set 2 | vaitape
# Processing Record 6 of Set 2 | longyearbyen
# Processing Record 7 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | leningradskiy
# Processing Record 10 of Set 2 | bathsheba
# Processing Record 11 of Set 2 | griffith
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | gornopravdinsk
# Processing Record 14 of Set 2 | klaksvik
# Processing Record 15 of Set 2 | vao
# Processing Record 16 of Set 2 | palembang
# Processing Record 17 of Set 2 | beian
# Processing Record 18 of Set 2 | codrington
# Processing Record 19 of Set 2 | khatanga
# Processing Record 20 of Set 2 | arraias
# Processing Record 21 of Set 2 | belmonte
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | hasaki
# Processing Record 24 of Set 2 | nanortalik
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | teya
# Processing Record 27 of Set 2 | chulman
# Processing Record 28 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | kahramanmaras
# Processing Record 31 of Set 2 | bardiyah
# Processing Record 32 of Set 2 | gamba
# Processing Record 33 of Set 2 | sur
# Processing Record 34 of Set 2 | havre-saint-pierre
# Processing Record 35 of Set 2 | san patricio
# Processing Record 36 of Set 2 | dunmore town
# Processing Record 37 of Set 2 | fortuna
# Processing Record 38 of Set 2 | balikpapan
# Processing Record 39 of Set 2 | carnarvon
# Processing Record 40 of Set 2 | airai
# Processing Record 41 of Set 2 | mandali
# Processing Record 42 of Set 2 | new norfolk
# Processing Record 43 of Set 2 | east london
# Processing Record 44 of Set 2 | barrow
# Processing Record 45 of Set 2 | bonavista
# Processing Record 46 of Set 2 | puerto ayora
# Processing Record 47 of Set 2 | yerbogachen
# Processing Record 48 of Set 2 | husavik
# Processing Record 49 of Set 2 | bluff
# Processing Record 50 of Set 2 | butaritari
# Processing Record 1 of Set 3 | yar-sale
# Processing Record 2 of Set 3 | jamestown
# Processing Record 3 of Set 3 | sinnamary
# Processing Record 4 of Set 3 | arraial do cabo
# Processing Record 5 of Set 3 | tuktoyaktuk
# Processing Record 6 of Set 3 | marsabit
# Processing Record 7 of Set 3 | cidreira
# Processing Record 8 of Set 3 | waitati
# Processing Record 9 of Set 3 | changping
# Processing Record 10 of Set 3 | paso de carrasco
# Processing Record 11 of Set 3 | souillac
# Processing Record 12 of Set 3 | cabedelo
# Processing Record 13 of Set 3 | kodiak
# Processing Record 14 of Set 3 | bagdarin
# Processing Record 15 of Set 3 | saint-philippe
# Processing Record 16 of Set 3 | torbay
# Processing Record 17 of Set 3 | rawson
# Processing Record 18 of Set 3 | aquiraz
# Processing Record 19 of Set 3 | pevek
# Processing Record 20 of Set 3 | sao miguel
# Processing Record 21 of Set 3 | guerrero negro
# Processing Record 22 of Set 3 | zhigansk
# Processing Record 23 of Set 3 | sitka
# Processing Record 24 of Set 3 | merauke
# Processing Record 25 of Set 3 | ilulissat
# Processing Record 26 of Set 3 | namibe
# Processing Record 27 of Set 3 | rajur
# Processing Record 28 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 3 | strelka
# Processing Record 30 of Set 3 | santa catalina
# Processing Record 31 of Set 3 | wamba
# Processing Record 32 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 3 | saldanha
# Processing Record 34 of Set 3 | bengkulu
# Processing Record 35 of Set 3 | poronaysk
# Processing Record 36 of Set 3 | boyolangu
# Processing Record 37 of Set 3 | noumea
# Processing Record 38 of Set 3 | honiara
# Processing Record 39 of Set 3 | gold coast
# Processing Record 40 of Set 3 | yazd
# Processing Record 41 of Set 3 | chissamba
# Processing Record 42 of Set 3 | luderitz
# Processing Record 43 of Set 3 | umm lajj
# Processing Record 44 of Set 3 | keetmanshoop
# Processing Record 45 of Set 3 | chuy
# Processing Record 46 of Set 3 | ribeira grande
# Processing Record 47 of Set 3 | cudahy
# Processing Record 48 of Set 3 | yashkino
# Processing Record 49 of Set 3 | jasper
# Processing Record 50 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 1 of Set 4 | lyubytino
# Processing Record 2 of Set 4 | mecca
# Processing Record 3 of Set 4 | garoua
# Processing Record 4 of Set 4 | wajima
# Processing Record 5 of Set 4 | freeport
# Processing Record 6 of Set 4 | petrolina
# Processing Record 7 of Set 4 | luwuk
# Processing Record 8 of Set 4 | tupiza
# Processing Record 9 of Set 4 | tigil
# Processing Record 10 of Set 4 | young
# Processing Record 11 of Set 4 | novobiryusinskiy
# Processing Record 12 of Set 4 | khor
# Processing Record 13 of Set 4 | nador
# Processing Record 14 of Set 4 | ylivieska
# Processing Record 15 of Set 4 | kiama
# Processing Record 16 of Set 4 | nikolskoye
# Processing Record 17 of Set 4 | castro
# Processing Record 18 of Set 4 | vestmannaeyjar
# Processing Record 19 of Set 4 | deputatskiy
# Processing Record 20 of Set 4 | mandalgovi
# Processing Record 21 of Set 4 | manta
# Processing Record 22 of Set 4 | qena
# Processing Record 23 of Set 4 | siuna
# Processing Record 24 of Set 4 | clyde river
# Processing Record 25 of Set 4 | ascension
# Processing Record 26 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 4 | khromtau
# Processing Record 28 of Set 4 | kralendijk
# Processing Record 29 of Set 4 | shelburne
# Processing Record 30 of Set 4 | kaya
# Processing Record 31 of Set 4 | high level
# Processing Record 32 of Set 4 | mehamn
# Processing Record 33 of Set 4 | general roca
# Processing Record 34 of Set 4 | matamoros
# Processing Record 35 of Set 4 | ketchikan
# Processing Record 36 of Set 4 | saint george
# Processing Record 37 of Set 4 | araouane
# Processing Record 38 of Set 4 | kloulklubed
# Processing Record 39 of Set 4 | qandala
# Processing Record 40 of Set 4 | cabo san lucas
# Processing Record 41 of Set 4 | alyangula
# Processing Record 42 of Set 4 | neftcala
# Processing Record 43 of Set 4 | broken hill
# Processing Record 44 of Set 4 | el ocotito
# Processing Record 45 of Set 4 | nchelenge
# Processing Record 46 of Set 4 | disna
# Processing Record 47 of Set 4 | camalu
# Processing Record 48 of Set 4 | tura
# Processing Record 49 of Set 4 | puerto gaitan
# Processing Record 50 of Set 4 | brae
# Processing Record 1 of Set 5 | vila franca do campo
# Processing Record 2 of Set 5 | auxerre
# Processing Record 3 of Set 5 | maceio
# Processing Record 4 of Set 5 | san cristobal
# Processing Record 5 of Set 5 | maputo
# Processing Record 6 of Set 5 | itarema
# Processing Record 7 of Set 5 | chokurdakh
# Processing Record 8 of Set 5 | troitsko-pechorsk
# Processing Record 9 of Set 5 | saskylakh
# Processing Record 10 of Set 5 | mana
# Processing Record 11 of Set 5 | shaowu
# Processing Record 12 of Set 5 | ukiah
# Processing Record 13 of Set 5 | sao joao da barra
# Processing Record 14 of Set 5 | dingle
# Processing Record 15 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 16 of Set 5 | krutaya gorka
# Processing Record 17 of Set 5 | khanpur
# Processing Record 18 of Set 5 | mikuni
# Processing Record 19 of Set 5 | buala
# Processing Record 20 of Set 5 | padang
# Processing Record 21 of Set 5 | oroville
# Processing Record 22 of Set 5 | ziro
# Processing Record 23 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 5 | panguna
# Processing Record 25 of Set 5 | dondo
# Processing Record 26 of Set 5 | kavieng
# Processing Record 27 of Set 5 | buraydah
# Processing Record 28 of Set 5 | erie
# Processing Record 29 of Set 5 | ballstad
# City not found. Skipping...
# Processing Record 30 of Set 5 | college
# Processing Record 31 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 32 of Set 5 | corrente
# Processing Record 33 of Set 5 | susehri
# Processing Record 34 of Set 5 | mahebourg
# Processing Record 35 of Set 5 | chernyshevskiy
# Processing Record 36 of Set 5 | bredasdorp
# Processing Record 37 of Set 5 | geraldton
# Processing Record 38 of Set 5 | jaipur hat
# City not found. Skipping...
# Processing Record 39 of Set 5 | puerto escondido
# Processing Record 40 of Set 5 | angoche
# Processing Record 41 of Set 5 | mankera
# Processing Record 42 of Set 5 | martvili
# Processing Record 43 of Set 5 | hereford
# Processing Record 44 of Set 5 | spornoye
# Processing Record 45 of Set 5 | norman wells
# Processing Record 46 of Set 5 | bethel
# Processing Record 47 of Set 5 | bandar
# Processing Record 48 of Set 5 | provideniya
# Processing Record 49 of Set 5 | aklavik
# Processing Record 50 of Set 5 | tiksi
# Processing Record 1 of Set 6 | dormidontovka
# Processing Record 2 of Set 6 | lodja
# Processing Record 3 of Set 6 | tarko-sale
# Processing Record 4 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 5 of Set 6 | aswan
# Processing Record 6 of Set 6 | ulaangom
# Processing Record 7 of Set 6 | lompoc
# Processing Record 8 of Set 6 | rumoi
# Processing Record 9 of Set 6 | cabinda
# Processing Record 10 of Set 6 | verkhoyansk
# Processing Record 11 of Set 6 | sayansk
# Processing Record 12 of Set 6 | bireun
# Processing Record 13 of Set 6 | alofi
# Processing Record 14 of Set 6 | springbok
# Processing Record 15 of Set 6 | jalu
# Processing Record 16 of Set 6 | linares
# Processing Record 17 of Set 6 | tuatapere
# Processing Record 18 of Set 6 | porangatu
# Processing Record 19 of Set 6 | katsuura
# Processing Record 20 of Set 6 | colesberg
# Processing Record 21 of Set 6 | nemuro
# Processing Record 22 of Set 6 | amos
# Processing Record 23 of Set 6 | huarmey
# Processing Record 24 of Set 6 | esperance
# Processing Record 25 of Set 6 | port blair
# Processing Record 26 of Set 6 | lensk
# Processing Record 27 of Set 6 | broome
# Processing Record 28 of Set 6 | cherskiy
# Processing Record 29 of Set 6 | varberg
# Processing Record 30 of Set 6 | bambous virieux
# Processing Record 31 of Set 6 | la paz
# Processing Record 32 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 6 | comodoro rivadavia
# Processing Record 34 of Set 6 | zhezkazgan
# Processing Record 35 of Set 6 | zhaotong
# Processing Record 36 of Set 6 | dalinghe
# City not found. Skipping...
# Processing Record 37 of Set 6 | sibu
# Processing Record 38 of Set 6 | korla
# Processing Record 39 of Set 6 | mazatlan
# Processing Record 40 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 6 | seoul
# Processing Record 42 of Set 6 | lampa
# Processing Record 43 of Set 6 | sangar
# Processing Record 44 of Set 6 | seymchan
# Processing Record 45 of Set 6 | solnechnyy
# Processing Record 46 of Set 6 | tadine
# Processing Record 47 of Set 6 | immokalee
# Processing Record 48 of Set 6 | sola
# Processing Record 49 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 50 of Set 6 | westport
# Processing Record 1 of Set 7 | bintulu
# Processing Record 2 of Set 7 | andenes
# Processing Record 3 of Set 7 | burnie
# Processing Record 4 of Set 7 | nerja
# Processing Record 5 of Set 7 | vodnyy
# Processing Record 6 of Set 7 | ayagoz
# Processing Record 7 of Set 7 | rabo de peixe
# Processing Record 8 of Set 7 | dmanisi
# Processing Record 9 of Set 7 | conde
# Processing Record 10 of Set 7 | medea
# Processing Record 11 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 7 | coihaique
# Processing Record 13 of Set 7 | peruibe
# Processing Record 14 of Set 7 | chingirlau
# Processing Record 15 of Set 7 | rio gallegos
# Processing Record 16 of Set 7 | waingapu
# Processing Record 17 of Set 7 | mount gambier
# Processing Record 18 of Set 7 | lagoa
# Processing Record 19 of Set 7 | ucluelet
# Processing Record 20 of Set 7 | ngunguru
# Processing Record 21 of Set 7 | middelburg
# Processing Record 22 of Set 7 | sa kaeo
# Processing Record 23 of Set 7 | flagstaff
# Processing Record 24 of Set 7 | garowe
# Processing Record 25 of Set 7 | jawhar
# Processing Record 26 of Set 7 | krasnotorka
# Processing Record 27 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 29 of Set 7 | nizwa
# Processing Record 30 of Set 7 | bulungu
# Processing Record 31 of Set 7 | lorengau
# Processing Record 32 of Set 7 | grand gaube
# Processing Record 33 of Set 7 | kropotkin
# Processing Record 34 of Set 7 | kijang
# Processing Record 35 of Set 7 | kalmunai
# Processing Record 36 of Set 7 | vila do maio
# Processing Record 37 of Set 7 | beloha
# Processing Record 38 of Set 7 | saint-pierre
# Processing Record 39 of Set 7 | saint-francois
# Processing Record 40 of Set 7 | mersing
# Processing Record 41 of Set 7 | ailigandi
# Processing Record 42 of Set 7 | etchojoa
# Processing Record 43 of Set 7 | olinda
# Processing Record 44 of Set 7 | chapais
# Processing Record 45 of Set 7 | bandiagara
# Processing Record 46 of Set 7 | muros
# Processing Record 47 of Set 7 | pangnirtung
# Processing Record 48 of Set 7 | belaya gora
# Processing Record 49 of Set 7 | srednekolymsk
# Processing Record 50 of Set 7 | kulachi
# Processing Record 1 of Set 8 | bloomingdale
# Processing Record 2 of Set 8 | ulaanbaatar
# Processing Record 3 of Set 8 | vila velha
# Processing Record 4 of Set 8 | pindwara
# Processing Record 5 of Set 8 | witu
# Processing Record 6 of Set 8 | guantanamo
# Processing Record 7 of Set 8 | kibaha
# Processing Record 8 of Set 8 | nouakchott
# Processing Record 9 of Set 8 | rafai
# Processing Record 10 of Set 8 | krasnoselkup
# Processing Record 11 of Set 8 | klenovyy
# Processing Record 12 of Set 8 | cazaje
# City not found. Skipping...
# Processing Record 13 of Set 8 | wucheng
# Processing Record 14 of Set 8 | thinadhoo
# Processing Record 15 of Set 8 | hambantota
# Processing Record 16 of Set 8 | grindavik
# Processing Record 17 of Set 8 | lithakia
# Processing Record 18 of Set 8 | ketchenery
# City not found. Skipping...
# Processing Record 19 of Set 8 | erzurum
# Processing Record 20 of Set 8 | sovetskaya gavan
# Processing Record 21 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 8 | victoria
# Processing Record 23 of Set 8 | riyadh
# Processing Record 24 of Set 8 | soavinandriana
# Processing Record 25 of Set 8 | sabancuy
# Processing Record 26 of Set 8 | pitimbu
# Processing Record 27 of Set 8 | nantucket
# Processing Record 28 of Set 8 | mayumba
# Processing Record 29 of Set 8 | bam
# Processing Record 30 of Set 8 | thompson
# Processing Record 31 of Set 8 | mount isa
# Processing Record 32 of Set 8 | awbari
# Processing Record 33 of Set 8 | parczew
# Processing Record 34 of Set 8 | dawson creek
# Processing Record 35 of Set 8 | eyl
# Processing Record 36 of Set 8 | ambon
# Processing Record 37 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 8 | lingao
# Processing Record 39 of Set 8 | pandan
# Processing Record 40 of Set 8 | kerema
# Processing Record 41 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 8 | faanui
# Processing Record 43 of Set 8 | alta floresta
# Processing Record 44 of Set 8 | sao filipe
# Processing Record 45 of Set 8 | porto novo
# Processing Record 46 of Set 8 | plettenberg bay
# Processing Record 47 of Set 8 | yithion
# City not found. Skipping...
# Processing Record 48 of Set 8 | bowen
# Processing Record 49 of Set 8 | zima
# Processing Record 50 of Set 8 | buchanan
# Processing Record 1 of Set 9 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 2 of Set 9 | nova olimpia
# Processing Record 3 of Set 9 | paramonga
# Processing Record 4 of Set 9 | hofn
# Processing Record 5 of Set 9 | mucuri
# Processing Record 6 of Set 9 | ipswich
# Processing Record 7 of Set 9 | baiao
# Processing Record 8 of Set 9 | kichmengskiy gorodok
# Processing Record 9 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 10 of Set 9 | eagle
# Processing Record 11 of Set 9 | nakkila
# Processing Record 12 of Set 9 | shumskiy
# Processing Record 13 of Set 9 | najran
# Processing Record 14 of Set 9 | puerto suarez
# Processing Record 15 of Set 9 | ramhormoz
# Processing Record 16 of Set 9 | dayong
# Processing Record 17 of Set 9 | bo
# City not found. Skipping...
# Processing Record 18 of Set 9 | nyurba
# Processing Record 19 of Set 9 | haicheng
# Processing Record 20 of Set 9 | guarapari
# Processing Record 21 of Set 9 | kimbe
# Processing Record 22 of Set 9 | ko samui
# Processing Record 23 of Set 9 | cayenne
# Processing Record 24 of Set 9 | sakaiminato
# Processing Record 25 of Set 9 | banamba
# Processing Record 26 of Set 9 | bandarbeyla
# Processing Record 27 of Set 9 | champerico
# Processing Record 28 of Set 9 | rauma
# Processing Record 29 of Set 9 | maneromango
# Processing Record 30 of Set 9 | sabha
# Processing Record 31 of Set 9 | palmer
# Processing Record 32 of Set 9 | los llanos de aridane
# Processing Record 33 of Set 9 | narsaq
# Processing Record 34 of Set 9 | ayan
# Processing Record 35 of Set 9 | nova floresta
# Processing Record 36 of Set 9 | ballina
# Processing Record 37 of Set 9 | manokwari
# Processing Record 38 of Set 9 | grand island
# Processing Record 39 of Set 9 | libreville
# Processing Record 40 of Set 9 | kaduqli
# Processing Record 41 of Set 9 | port hedland
# Processing Record 42 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 43 of Set 9 | marawi
# Processing Record 44 of Set 9 | perelyub
# Processing Record 45 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 46 of Set 9 | puerto padre
# Processing Record 47 of Set 9 | digby
# Processing Record 48 of Set 9 | urucara
# Processing Record 49 of Set 9 | coquimbo
# Processing Record 50 of Set 9 | hayrabolu
# Processing Record 1 of Set 10 | urengoy
# Processing Record 2 of Set 10 | dudhani
# Processing Record 3 of Set 10 | hami
# Processing Record 4 of Set 10 | isangel
# Processing Record 5 of Set 10 | kang
# Processing Record 6 of Set 10 | jianhu
# Processing Record 7 of Set 10 | jumla
# Processing Record 8 of Set 10 | cravo norte
# Processing Record 9 of Set 10 | tessalit
# Processing Record 10 of Set 10 | maldonado
# Processing Record 11 of Set 10 | svetlogorsk
# Processing Record 12 of Set 10 | kyabe
# Processing Record 13 of Set 10 | harper
# Processing Record 14 of Set 10 | ayolas
# Processing Record 15 of Set 10 | marmaron
# City not found. Skipping...
# Processing Record 16 of Set 10 | torgelow
# Processing Record 17 of Set 10 | harlingen
# Processing Record 18 of Set 10 | severo-kurilsk
# Processing Record 19 of Set 10 | hit
# Processing Record 20 of Set 10 | pacific grove
# Processing Record 21 of Set 10 | sanghar
# Processing Record 22 of Set 10 | maningrida
# Processing Record 23 of Set 10 | taoudenni
# Processing Record 24 of Set 10 | menongue
# Processing Record 25 of Set 10 | kaitangata
# Processing Record 26 of Set 10 | liwale
# Processing Record 27 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 10 | zavodskoy
# Processing Record 29 of Set 10 | wanlaweyn
# Processing Record 30 of Set 10 | zhuhai
# Processing Record 31 of Set 10 | baker city
# Processing Record 32 of Set 10 | khuzhir
# Processing Record 33 of Set 10 | natal
# Processing Record 34 of Set 10 | pokhara
# Processing Record 35 of Set 10 | kidal
# Processing Record 36 of Set 10 | peniche
# Processing Record 37 of Set 10 | jacmel
# Processing Record 38 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 10 | kita
# Processing Record 40 of Set 10 | dwarka
# Processing Record 41 of Set 10 | nuuk
# Processing Record 42 of Set 10 | santa rosa
# Processing Record 43 of Set 10 | pontiac
# Processing Record 44 of Set 10 | pinsk
# Processing Record 45 of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record 46 of Set 10 | moron
# Processing Record 47 of Set 10 | la ronge
# Processing Record 48 of Set 10 | kenai
# Processing Record 49 of Set 10 | clearwater
# Processing Record 50 of Set 10 | naryan-mar
# Processing Record 1 of Set 11 | ulagan
# Processing Record 2 of Set 11 | sorland
# Processing Record 3 of Set 11 | khandyga
# Processing Record 4 of Set 11 | ostrovnoy
# Processing Record 5 of Set 11 | lasa
# Processing Record 6 of Set 11 | guozhen
# Processing Record 7 of Set 11 | asau
# Processing Record 8 of Set 11 | leh
# Processing Record 9 of Set 11 | kasongo-lunda
# Processing Record 10 of Set 11 | cheremukhovo
# Processing Record 11 of Set 11 | madera
# Processing Record 12 of Set 11 | surin
# Processing Record 13 of Set 11 | henties bay
# Processing Record 14 of Set 11 | darhan
# Processing Record 15 of Set 11 | druzhba
# Processing Record 16 of Set 11 | san jeronimo
# Processing Record 17 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 11 | labuhan
# Processing Record 19 of Set 11 | jhargram
# Processing Record 20 of Set 11 | tarut
# Processing Record 21 of Set 11 | honningsvag
# Processing Record 22 of Set 11 | tombouctou
# Processing Record 23 of Set 11 | sibay
# Processing Record 24 of Set 11 | rio branco
# Processing Record 25 of Set 11 | strezhevoy
# Processing Record 26 of Set 11 | marcon
# Processing Record 27 of Set 11 | jibuti
# Processing Record 28 of Set 11 | dryden
# Processing Record 29 of Set 11 | zaozerne
# Processing Record 30 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 31 of Set 11 | opuwo
# Processing Record 32 of Set 11 | coatzacoalcos
# Processing Record 33 of Set 11 | abomey
# Processing Record 34 of Set 11 | beringovskiy
# Processing Record 35 of Set 11 | la crosse
# Processing Record 36 of Set 11 | sandakan
# Processing Record 37 of Set 11 | cajamarca
# Processing Record 38 of Set 11 | ormara
# Processing Record 39 of Set 11 | cockburn town
# Processing Record 40 of Set 11 | tautira
# Processing Record 41 of Set 11 | maloshuyka
# City not found. Skipping...
# Processing Record 42 of Set 11 | bauchi
# Processing Record 43 of Set 11 | elliot lake
# Processing Record 44 of Set 11 | makat
# Processing Record 45 of Set 11 | san quintin
# Processing Record 46 of Set 11 | poum
# Processing Record 47 of Set 11 | kipushi
# Processing Record 48 of Set 11 | balad
# Processing Record 49 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 50 of Set 11 | jizan
# Processing Record 1 of Set 12 | alihe
# Processing Record 2 of Set 12 | kanelovskaya
# Processing Record 3 of Set 12 | umm kaddadah
# Processing Record 4 of Set 12 | omboue
# Processing Record 5 of Set 12 | port lincoln
# Processing Record 6 of Set 12 | kyren
# Processing Record 7 of Set 12 | faya
# Processing Record 8 of Set 12 | yanam

# %%
city_data.head(10)
